# %% [markdown]
# ## Practical No.5: Write a NumPy program to implement following operation
# ### • to find the maximum and minimum value of a given flattened array

# %%
# Name : Kishan B. Lashkari
# Enrollment No : 216270307002

import numpy as np

arr = np.array([[30,20,25],[35,45,40]])

print("Original Array : ",end="")
print(arr)

print("Maximum Value : ",end="")
max = np.amax(arr)
print(max)

print("Minimum Value : ",end="")
min = np.amin(arr)
print(min)

# %% [markdown]
# ### • to compute the mean, standard deviation, and variance of a given array along the second axis

# %%
# Name : Kishan B. Lashkari
# Enrollment : 216270307002

import numpy as np

arr = np.array([[19,20,21],[10,20,30]])

print("Original array : ",end="")
print(arr)

mean = np.mean(arr, axis = 1)
print("Mean Value : ",end="")
print(mean)

std = np.std(arr, axis = 1)
print("Standar Deviation : ",end="")
print(std)

var = np.var(arr, axis = 1)
print("Variance : ",end="")
print(var)
